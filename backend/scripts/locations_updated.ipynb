# %%
import requests
import json
import random
import time

# Base URL of the FastAPI server
BASE_URL = "http://localhost:8000"

# Optional: user_id for personalized /locations/recommended
# Get this from /auth/login if you want to test recommendations
USER_ID = "4e1a0d19-a99a-4395-935c-7746cad56b70"  # e.g. "6e0e5c7e-1234-4567-890a-bcdef1234567"

HEADERS = {"X-User-ID": USER_ID} if USER_ID else {}

print("BASE_URL =", BASE_URL)
print("USER_ID =", USER_ID)
# Out:
# BASE_URL = http://localhost:8000
# USER_ID = 4e1a0d19-a99a-4395-935c-7746cad56b70

# %%
location_names = [
    "Victoria Peak", "Lion Rock", "Dragon's Back", "Mount Parker", "Lantau Peak",
    "Tai Mo Shan", "Sharp Peak", "Sunset Peak", "Needle Hill", "Ma On Shan",
    "High West", "Pat Sin Leng", "Jardine's Lookout", "The Twins", "Castle Peak",
    "Pineapple Mountain", "Shing Mun Reservoir", "Aberdeen Peak", "Clear Water Bay Peak",
    "Ap Lei Chau Trail", "Cape D’Aguilar", "Sai Wan Peak", "Hawk's Nest", "Tung Chung Valley"
]

areas = ["Central", "Kowloon", "New Territories", "Lantau", "Hong Kong Island"]
price_levels = [1, 2, 3, 4]

bulk_created_ids = []

for name in location_names:
    payload = {
        "name": name,
        "description": f"A scenic location known as {name}.",
        "maps_url": "https://maps.example.com",
        "price_level": random.choice(price_levels),
        "area": random.choice(areas),
    }

    url = f"{BASE_URL}/locations/"
    try:
        res = requests.post(url, json=payload)
        print(f"Created {name} → Status {res.status_code}")
        print('Status:', res.status_code)
        print('Response:', res.text)
        data = res.json()
        loc_id = data.get("id")
        if loc_id:
            bulk_created_ids.append(loc_id)
    except Exception as e:
        print(f"Error creating {name}: {e}")

time.sleep(0.5)
print("\nTotal created:", len(bulk_created_ids))
bulk_created_ids[:5]
# Out:
# Created Victoria Peak → Status 200
# Status: 200
# Response: {"name":"Victoria Peak","description":"A scenic location known as Victoria Peak.","maps_url":"https://maps.example.com","price_level":1,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"99dfd506-e8de-44dc-ae06-7dfa7a2e8c44","created_at":"2025-11-23T20:42:13.445102+08:00"}
# Created Lion Rock → Status 200
# Status: 200
# Response: {"name":"Lion Rock","description":"A scenic location known as Lion Rock.","maps_url":"https://maps.example.com","price_level":3,"area":"Hong Kong Island","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"be3ffa45-7a2d-4381-a96d-81154c801e9d","created_at":"2025-11-23T20:42:13.463081+08:00"}
# Created Dragon's Back → Status 200
# Status: 200
# Response: {"name":"Dragon's Back","description":"A scenic location known as Dragon's Back.","maps_url":"https://maps.example.com","price_level":1,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"04ef8073-3fa4-4188-a24b-3101c92151a5","created_at":"2025-11-23T20:42:13.471455+08:00"}
# Created Mount Parker → Status 200
# Status: 200
# Response: {"name":"Mount Parker","description":"A scenic location known as Mount Parker.","maps_url":"https://maps.example.com","price_level":1,"area":"Hong Kong Island","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"2ccd5693-d3f8-4d68-bfbe-3009ef7d565f","created_at":"2025-11-23T20:42:13.479201+08:00"}
# Created Lantau Peak → Status 200
# Status: 200
# Response: {"name":"Lantau Peak","description":"A scenic location known as Lantau Peak.","maps_url":"https://maps.example.com","price_level":3,"area":"New Territories","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"8d6aa028-af5d-4220-bc0a-6680ec14e7b3","created_at":"2025-11-23T20:42:13.483999+08:00"}
# Created Tai Mo Shan → Status 200
# Status: 200
# Response: {"name":"Tai Mo Shan","description":"A scenic location known as Tai Mo Shan.","maps_url":"https://maps.example.com","price_level":1,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"5fa99804-8961-49a5-97a8-669d3542b701","created_at":"2025-11-23T20:42:13.489372+08:00"}
# Created Sharp Peak → Status 200
# Status: 200
# Response: {"name":"Sharp Peak","description":"A scenic location known as Sharp Peak.","maps_url":"https://maps.example.com","price_level":4,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"029f38ec-fdbb-4e83-916f-3b1780e9e4d0","created_at":"2025-11-23T20:42:13.494942+08:00"}
# Created Sunset Peak → Status 200
# Status: 200
# Response: {"name":"Sunset Peak","description":"A scenic location known as Sunset Peak.","maps_url":"https://maps.example.com","price_level":2,"area":"Lantau","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"0488e284-214b-441a-a7fa-d0155e7adb1b","created_at":"2025-11-23T20:42:13.503425+08:00"}
# Created Needle Hill → Status 200
# Status: 200
# Response: {"name":"Needle Hill","description":"A scenic location known as Needle Hill.","maps_url":"https://maps.example.com","price_level":2,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"a1fe18a0-5c13-4452-8b2b-28d3f8d08685","created_at":"2025-11-23T20:42:13.508515+08:00"}
# Created Ma On Shan → Status 200
# Status: 200
# Response: {"name":"Ma On Shan","description":"A scenic location known as Ma On Shan.","maps_url":"https://maps.example.com","price_level":2,"area":"New Territories","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"f155f7f3-ff41-4c4b-b7d5-211d7ed8fdd5","created_at":"2025-11-23T20:42:13.513771+08:00"}
# Created High West → Status 200
# Status: 200
# Response: {"name":"High West","description":"A scenic location known as High West.","maps_url":"https://maps.example.com","price_level":4,"area":"Lantau","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"5e8fca7c-b63a-4ac1-b4a7-a2d9e64f790f","created_at":"2025-11-23T20:42:13.520551+08:00"}
# Created Pat Sin Leng → Status 200
# Status: 200
# Response: {"name":"Pat Sin Leng","description":"A scenic location known as Pat Sin Leng.","maps_url":"https://maps.example.com","price_level":1,"area":"Kowloon","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"5bcdf21e-3fd0-4b6b-82f6-f9fd98b714ee","created_at":"2025-11-23T20:42:13.526496+08:00"}
# Created Jardine's Lookout → Status 200
# Status: 200
# Response: {"name":"Jardine's Lookout","description":"A scenic location known as Jardine's Lookout.","maps_url":"https://maps.example.com","price_level":2,"area":"Lantau","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"e445ed36-a2c4-4be1-bf69-704fedd41b38","created_at":"2025-11-23T20:42:13.531257+08:00"}
# Created The Twins → Status 200
# Status: 200
# Response: {"name":"The Twins","description":"A scenic location known as The Twins.","maps_url":"https://maps.example.com","price_level":3,"area":"Hong Kong Island","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"13cfb858-c4bc-4410-a505-682d25ab8762","created_at":"2025-11-23T20:42:13.536400+08:00"}
# Created Castle Peak → Status 200
# Status: 200
# Response: {"name":"Castle Peak","description":"A scenic location known as Castle Peak.","maps_url":"https://maps.example.com","price_level":2,"area":"Lantau","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"7e0b4cde-d332-4cfc-a0f4-b06c0c26871e","created_at":"2025-11-23T20:42:13.540938+08:00"}
# Created Pineapple Mountain → Status 200
# Status: 200
# Response: {"name":"Pineapple Mountain","description":"A scenic location known as Pineapple Mountain.","maps_url":"https://maps.example.com","price_level":1,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"1ab74c36-e33f-4269-968c-5725d8d3412f","created_at":"2025-11-23T20:42:13.546923+08:00"}
# Created Shing Mun Reservoir → Status 200
# Status: 200
# Response: {"name":"Shing Mun Reservoir","description":"A scenic location known as Shing Mun Reservoir.","maps_url":"https://maps.example.com","price_level":3,"area":"Lantau","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"40f5cc8a-2392-4ee4-9e0b-821f4af63e66","created_at":"2025-11-23T20:42:13.551522+08:00"}
# Created Aberdeen Peak → Status 200
# Status: 200
# Response: {"name":"Aberdeen Peak","description":"A scenic location known as Aberdeen Peak.","maps_url":"https://maps.example.com","price_level":4,"area":"Hong Kong Island","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"a7272f31-9a0d-40e7-8db3-4de4aed4fdd2","created_at":"2025-11-23T20:42:13.555975+08:00"}
# Created Clear Water Bay Peak → Status 200
# Status: 200
# Response: {"name":"Clear Water Bay Peak","description":"A scenic location known as Clear Water Bay Peak.","maps_url":"https://maps.example.com","price_level":4,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"01cb1936-f029-47fa-afe0-14dd230e3ed6","created_at":"2025-11-23T20:42:13.561391+08:00"}
# Created Ap Lei Chau Trail → Status 200
# Status: 200
# Response: {"name":"Ap Lei Chau Trail","description":"A scenic location known as Ap Lei Chau Trail.","maps_url":"https://maps.example.com","price_level":1,"area":"New Territories","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"d6524ceb-93bd-45e1-8809-f68399afb22f","created_at":"2025-11-23T20:42:13.566221+08:00"}
# Created Cape D’Aguilar → Status 200
# Status: 200
# Response: {"name":"Cape D’Aguilar","description":"A scenic location known as Cape D’Aguilar.","maps_url":"https://maps.example.com","price_level":3,"area":"Hong Kong Island","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"d7eb1184-04a4-4d3c-b796-4346a02fd6c9","created_at":"2025-11-23T20:42:13.571258+08:00"}
# Created Sai Wan Peak → Status 200
# Status: 200
# Response: {"name":"Sai Wan Peak","description":"A scenic location known as Sai Wan Peak.","maps_url":"https://maps.example.com","price_level":3,"area":"Kowloon","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"8810db87-b2c4-44a1-bc50-caf1bf657cee","created_at":"2025-11-23T20:42:13.576750+08:00"}
# Created Hawk's Nest → Status 200
# Status: 200
# Response: {"name":"Hawk's Nest","description":"A scenic location known as Hawk's Nest.","maps_url":"https://maps.example.com","price_level":3,"area":"Kowloon","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"7b849cf7-63e2-4fa5-abbb-7d93bf250ec6","created_at":"2025-11-23T20:42:13.581976+08:00"}
# Created Tung Chung Valley → Status 200
# Status: 200
# Response: {"name":"Tung Chung Valley","description":"A scenic location known as Tung Chung Valley.","maps_url":"https://maps.example.com","price_level":1,"area":"Lantau","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"b3bf3702-4cf4-41ea-8059-fd3953250956","created_at":"2025-11-23T20:42:13.586264+08:00"}
#
# Total created: 24
# ['99dfd506-e8de-44dc-ae06-7dfa7a2e8c44',
#  'be3ffa45-7a2d-4381-a96d-81154c801e9d',
#  '04ef8073-3fa4-4188-a24b-3101c92151a5',
#  '2ccd5693-d3f8-4d68-bfbe-3009ef7d565f',
#  '8d6aa028-af5d-4220-bc0a-6680ec14e7b3']

# %%
url = f"{BASE_URL}/locations/"
res = requests.get(url)

print("Status:", res.status_code)
all_locations = res.json()
print("Total locations returned:", len(all_locations))
print(json.dumps(all_locations[:3], indent=2))  # show first 3
# Out:
# Status: 500
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[16], line 5
#       2 res = requests.get(url)
#       4 print("Status:", res.status_code)
# ----> 5 all_locations = res.json()
#       6 print("Total locations returned:", len(all_locations))
#       7 print(json.dumps(all_locations[:3], indent=2))  # show first 3
#
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# Example: filter by area and price_level
url = f"{BASE_URL}/locations/?area=Central&price_level=2"
res = requests.get(url)

print("Status:", res.status_code)
filtered_locations = res.json()
print("Filtered locations count:", len(filtered_locations))
print(json.dumps(filtered_locations[:3], indent=2))
# Out:
# Status: 500
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[9], line 6
#       3 res = requests.get(url)
#       5 print("Status:", res.status_code)
# ----> 6 filtered_locations = res.json()
#       7 print("Filtered locations count:", len(filtered_locations))
#       8 print(json.dumps(filtered_locations[:3], indent=2))
#
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
if bulk_created_ids:
    test_location_id = bulk_created_ids[0]
    print("Using test_location_id from bulk_created_ids:", test_location_id)
elif all_locations:
    test_location_id = all_locations[0]["id"]
    print("No bulk_created_ids, using first from all_locations:", test_location_id)
else:
    test_location_id = None
    print("No locations available to test.")

test_location_id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2     test_location_id = bulk_created_ids[0]
#       3     print("Using test_location_id from bulk_created_ids:", test_location_id)
# ----> 4 elif all_locations:
#       5     test_location_id = all_locations[0]["id"]
#       6     print("No bulk_created_ids, using first from all_locations:", test_location_id)
#
# NameError: name 'all_locations' is not defined

# %%
if not test_location_id:
    raise RuntimeError("No test_location_id available. Run previous cells first.")

url = f"{BASE_URL}/locations/{test_location_id}"
res = requests.get(url)

print("Status:", res.status_code)
print(json.dumps(res.json(), indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 if not test_location_id:
#       2     raise RuntimeError("No test_location_id available. Run previous cells first.")
#       4 url = f"{BASE_URL}/locations/{test_location_id}"
#
# NameError: name 'test_location_id' is not defined

# %%
update_payload = {
    "name": "Updated Test Location",
    "price_level": 3,
}

url = f"{BASE_URL}/locations/{test_location_id}"
res = requests.put(url, json=update_payload)

print("Status:", res.status_code)
print(json.dumps(res.json(), indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       1 update_payload = {
#       2     "name": "Updated Test Location",
#       3     "price_level": 3,
#       4 }
# ----> 6 url = f"{BASE_URL}/locations/{test_location_id}"
#       7 res = requests.put(url, json=update_payload)
#       9 print("Status:", res.status_code)
#
# NameError: name 'test_location_id' is not defined

# %%
import os

image_path = "test_image.jpg"  # change if needed

if os.path.exists(image_path):
    url = f"{BASE_URL}/locations/{test_location_id}/images"
    with open(image_path, "rb") as f:
        files = {"file": (os.path.basename(image_path), f, "image/jpeg")}
        res = requests.post(url, files=files)

    print("Status:", res.status_code)
    print(json.dumps(res.json(), indent=2))
else:
    print(f"Image file not found: {image_path}. Skipping image upload test.")

print('Status:', res.status_code)
print('Response:', res.text)
# Out:
# Image file not found: test_image.jpg. Skipping image upload test.
# Status: 500
# Response: Internal Server Error

# %%
tags_payload = {
    "tags": ["hiking", "scenic", "sunset"]
}

url = f"{BASE_URL}/locations/{test_location_id}/tags"
res = requests.post(url, json=tags_payload)

print("Status:", res.status_code)
tags_response = res.json()
print(json.dumps(tags_response, indent=2))

tag_ids = [t.get("id") for t in tags_response.get("added_tags", []) if t.get("id") is not None]
tag_ids

print('Status:', res.status_code)
print('Response:', res.text)

# %%
if tag_ids:
    tag_id = tag_ids[0]
    url = f"{BASE_URL}/locations/{test_location_id}/tags/{tag_id}"
    res = requests.delete(url)

    print("Status:", res.status_code)
    print(json.dumps(res.json(), indent=2))
else:
    print("No tag_ids available to delete.")

# %%
if not USER_ID:
    print("USER_ID is not set. Skipping /locations/recommended test.")
else:
    url = f"{BASE_URL}/locations/recommended?limit=10"
    res = requests.get(url, headers=HEADERS)
    print("Status:", res.status_code)
    print(json.dumps(res.json(), indent=2))
# Out:
# Status: 500
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[18], line 7
#       5 res = requests.get(url, headers=HEADERS)
#       6 print("Status:", res.status_code)
# ----> 7 print(json.dumps(res.json(), indent=2))
#
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
cleanup = False  # set to True if you want to delete the test location

if cleanup and test_location_id:
    url = f"{BASE_URL}/locations/{test_location_id}"
    res = requests.delete(url)
    print("Status:", res.status_code)
    print(json.dumps(res.json(), indent=2))
elif not cleanup:
    print("Cleanup is disabled. Set cleanup = True to delete the test location.")
else:
    print("No test_location_id to delete.")
# Out:
# Cleanup is disabled. Set cleanup = True to delete the test location.
