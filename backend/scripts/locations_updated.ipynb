# %%
import requests
import json
import random
import time

# Base URL of the FastAPI server
BASE_URL = "http://localhost:8000"

# Optional: user_id for personalized /locations/recommended
# Get this from /auth/login if you want to test recommendations
USER_ID = "4e1a0d19-a99a-4395-935c-7746cad56b70"  # e.g. "6e0e5c7e-1234-4567-890a-bcdef1234567"

HEADERS = {"X-User-ID": USER_ID} if USER_ID else {}

print("BASE_URL =", BASE_URL)
print("USER_ID =", USER_ID)
# Out:
# BASE_URL = http://localhost:8000
# USER_ID = 4e1a0d19-a99a-4395-935c-7746cad56b70

# %%
location_names = [
    "Victoria Peak", "Lion Rock", "Dragon's Back", "Mount Parker", "Lantau Peak",
    "Tai Mo Shan", "Sharp Peak", "Sunset Peak", "Needle Hill", "Ma On Shan",
    "High West", "Pat Sin Leng", "Jardine's Lookout", "The Twins", "Castle Peak",
    "Pineapple Mountain", "Shing Mun Reservoir", "Aberdeen Peak", "Clear Water Bay Peak",
    "Ap Lei Chau Trail", "Cape D’Aguilar", "Sai Wan Peak", "Hawk's Nest", "Tung Chung Valley"
]

areas = ["Central", "Kowloon", "New Territories", "Lantau", "Hong Kong Island"]
price_levels = [1, 2, 3, 4]

bulk_created_ids = []

for name in location_names:
    payload = {
        "name": name,
        "description": f"A scenic location known as {name}.",
        "maps_url": "https://maps.example.com",
        "price_level": random.choice(price_levels),
        "area": random.choice(areas),
    }

    url = f"{BASE_URL}/locations/"
    try:
        res = requests.post(url, json=payload)
        print(f"Created {name} → Status {res.status_code}")
        print('Status:', res.status_code)
        print('Response:', res.text)
        data = res.json()
        loc_id = data.get("id")
        if loc_id:
            bulk_created_ids.append(loc_id)
    except Exception as e:
        print(f"Error creating {name}: {e}")

time.sleep(0.5)
print("\nTotal created:", len(bulk_created_ids))
bulk_created_ids[:5]
# Out:
# Created Victoria Peak → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('a11541d8-ecd0-45b8-ad5e-3455c0c75b6b'), 'name': 'Victoria Peak', 'description': 'A scenic location known as Victoria Peak.', 'maps_url': 'https://maps.example.com', 'price_level': 4, 'area': 'Lantau', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 396179)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Lion Rock → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('cc25ccc8-b9b5-4408-b1ba-98dbf41fe64d'), 'name': 'Lion Rock', 'description': 'A scenic location known as Lion Rock.', 'maps_url': 'https://maps.example.com', 'price_level': 3, 'area': 'Central', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 402436)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Dragon's Back → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('740ba8d8-3d0c-4b38-bdb8-9495b6640666'), 'name': \"Dragon's Back\", 'description': \"A scenic location known as Dragon's Back.\", 'maps_url': 'https://maps.example.com', 'price_level': 2, 'area': 'Kowloon', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 420695)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Mount Parker → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('d8c35b2e-45a7-484f-8b05-8c929e8a7f9d'), 'name': 'Mount Parker', 'description': 'A scenic location known as Mount Parker.', 'maps_url': 'https://maps.example.com', 'price_level': 1, 'area': 'Hong Kong Island', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 445499)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Lantau Peak → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('63d91f62-968a-40c2-b0a7-941b99ea7d75'), 'name': 'Lantau Peak', 'description': 'A scenic location known as Lantau Peak.', 'maps_url': 'https://maps.example.com', 'price_level': 4, 'area': 'Hong Kong Island', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 456034)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Tai Mo Shan → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('f3977efb-fff3-4170-a067-ca595bba356c'), 'name': 'Tai Mo Shan', 'description': 'A scenic location known as Tai Mo Shan.', 'maps_url': 'https://maps.example.com', 'price_level': 4, 'area': 'Central', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 459696)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Sharp Peak → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('54dabe47-e39b-4c47-9387-5d1f6cf33b0f'), 'name': 'Sharp Peak', 'description': 'A scenic location known as Sharp Peak.', 'maps_url': 'https://maps.example.com', 'price_level': 2, 'area': 'New Territories', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 462524)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Sunset Peak → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('75f95f06-b331-4844-9fab-e3ca7d126996'), 'name': 'Sunset Peak', 'description': 'A scenic location known as Sunset Peak.', 'maps_url': 'https://maps.example.com', 'price_level': 1, 'area': 'New Territories', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 465328)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Needle Hill → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('54cd9f37-e77a-474a-894e-2620f89e60e9'), 'name': 'Needle Hill', 'description': 'A scenic location known as Needle Hill.', 'maps_url': 'https://maps.example.com', 'price_level': 2, 'area': 'Kowloon', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 468190)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Ma On Shan → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('ee537ec6-7f46-4ed6-99e5-21094271a73c'), 'name': 'Ma On Shan', 'description': 'A scenic location known as Ma On Shan.', 'maps_url': 'https://maps.example.com', 'price_level': 2, 'area': 'Central', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 471552)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created High West → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('4dd99a3d-cdb5-468e-a8ae-de92aeb41bbd'), 'name': 'High West', 'description': 'A scenic location known as High West.', 'maps_url': 'https://maps.example.com', 'price_level': 3, 'area': 'Central', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 474447)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Pat Sin Leng → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('93a404e6-cc4e-4b11-acd2-527893a5fe56'), 'name': 'Pat Sin Leng', 'description': 'A scenic location known as Pat Sin Leng.', 'maps_url': 'https://maps.example.com', 'price_level': 1, 'area': 'Lantau', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 477138)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Jardine's Lookout → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('3d9eb4ca-37a7-4831-af89-5fa4dc387c49'), 'name': \"Jardine's Lookout\", 'description': \"A scenic location known as Jardine's Lookout.\", 'maps_url': 'https://maps.example.com', 'price_level': 3, 'area': 'Hong Kong Island', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 479547)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created The Twins → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('4c15fd66-0e2b-477b-ba27-67d31341ee44'), 'name': 'The Twins', 'description': 'A scenic location known as The Twins.', 'maps_url': 'https://maps.example.com', 'price_level': 2, 'area': 'Central', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 482161)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Castle Peak → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('4b2af9a6-754d-4b32-a973-4d487e50b8c4'), 'name': 'Castle Peak', 'description': 'A scenic location known as Castle Peak.', 'maps_url': 'https://maps.example.com', 'price_level': 2, 'area': 'Hong Kong Island', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 484992)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Pineapple Mountain → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('d91c0f9c-cbfe-4841-b4f8-07ae40aff661'), 'name': 'Pineapple Mountain', 'description': 'A scenic location known as Pineapple Mountain.', 'maps_url': 'https://maps.example.com', 'price_level': 4, 'area': 'New Territories', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 488760)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Shing Mun Reservoir → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('d7f2a63a-d2ff-4e11-b89f-3c04f45eedb2'), 'name': 'Shing Mun Reservoir', 'description': 'A scenic location known as Shing Mun Reservoir.', 'maps_url': 'https://maps.example.com', 'price_level': 2, 'area': 'New Territories', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 491900)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Aberdeen Peak → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('d1f6beef-77c6-4d7d-9ad9-90e13b6d303d'), 'name': 'Aberdeen Peak', 'description': 'A scenic location known as Aberdeen Peak.', 'maps_url': 'https://maps.example.com', 'price_level': 1, 'area': 'New Territories', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 494765)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Clear Water Bay Peak → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('52bd73ec-85c4-403c-904e-b8691f641417'), 'name': 'Clear Water Bay Peak', 'description': 'A scenic location known as Clear Water Bay Peak.', 'maps_url': 'https://maps.example.com', 'price_level': 1, 'area': 'Kowloon', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 497725)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Ap Lei Chau Trail → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('130d6e3e-3d69-4722-801d-4816102e562f'), 'name': 'Ap Lei Chau Trail', 'description': 'A scenic location known as Ap Lei Chau Trail.', 'maps_url': 'https://maps.example.com', 'price_level': 4, 'area': 'Lantau', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 500442)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Cape D’Aguilar → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('0b0a81ba-8213-41c7-bb50-6c512ba74ba2'), 'name': 'Cape D’Aguilar', 'description': 'A scenic location known as Cape D’Aguilar.', 'maps_url': 'https://maps.example.com', 'price_level': 4, 'area': 'New Territories', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 503388)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Sai Wan Peak → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('046f4aab-58c2-4fe4-9d29-ea558549d59e'), 'name': 'Sai Wan Peak', 'description': 'A scenic location known as Sai Wan Peak.', 'maps_url': 'https://maps.example.com', 'price_level': 4, 'area': 'Central', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 506783)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Hawk's Nest → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('9146e639-133d-4edf-afd0-683b4a324fc1'), 'name': \"Hawk's Nest\", 'description': \"A scenic location known as Hawk's Nest.\", 'maps_url': 'https://maps.example.com', 'price_level': 2, 'area': 'New Territories', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 509747)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
# Created Tung Chung Valley → Status 500
# Status: 500
# Response: {"detail":"Database error: (psycopg2.errors.UndefinedColumn) column \"region\" of relation \"locations\" does not exist\nLINE 1: ..., name, description, maps_url, price_level, area, region, su...\n                                                             ^\n\n[SQL: INSERT INTO locations (id, name, description, maps_url, price_level, area, region, summary, duration, opening_hours, created_at) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(maps_url)s, %(price_level)s, %(area)s, %(region)s, %(summary)s, %(duration)s, %(opening_hours)s, %(created_at)s)]\n[parameters: {'id': UUID('5a4fea66-a4f3-4607-9cbc-18dac7ddd9ba'), 'name': 'Tung Chung Valley', 'description': 'A scenic location known as Tung Chung Valley.', 'maps_url': 'https://maps.example.com', 'price_level': 3, 'area': 'Kowloon', 'region': None, 'summary': None, 'duration': None, 'opening_hours': None, 'created_at': datetime.datetime(2025, 11, 23, 20, 9, 46, 512234)}]\n(Background on this error at: https://sqlalche.me/e/20/f405)"}
#
# Total created: 0
# []

# %%
url = f"{BASE_URL}/locations/"
res = requests.get(url)

print("Status:", res.status_code)
all_locations = res.json()
print("Total locations returned:", len(all_locations))
print(json.dumps(all_locations[:3], indent=2))  # show first 3
# Out:
# Status: 500
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[16], line 5
#       2 res = requests.get(url)
#       4 print("Status:", res.status_code)
# ----> 5 all_locations = res.json()
#       6 print("Total locations returned:", len(all_locations))
#       7 print(json.dumps(all_locations[:3], indent=2))  # show first 3
#
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
# Example: filter by area and price_level
url = f"{BASE_URL}/locations/?area=Central&price_level=2"
res = requests.get(url)

print("Status:", res.status_code)
filtered_locations = res.json()
print("Filtered locations count:", len(filtered_locations))
print(json.dumps(filtered_locations[:3], indent=2))
# Out:
# Status: 500
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[9], line 6
#       3 res = requests.get(url)
#       5 print("Status:", res.status_code)
# ----> 6 filtered_locations = res.json()
#       7 print("Filtered locations count:", len(filtered_locations))
#       8 print(json.dumps(filtered_locations[:3], indent=2))
#
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
if bulk_created_ids:
    test_location_id = bulk_created_ids[0]
    print("Using test_location_id from bulk_created_ids:", test_location_id)
elif all_locations:
    test_location_id = all_locations[0]["id"]
    print("No bulk_created_ids, using first from all_locations:", test_location_id)
else:
    test_location_id = None
    print("No locations available to test.")

test_location_id
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2     test_location_id = bulk_created_ids[0]
#       3     print("Using test_location_id from bulk_created_ids:", test_location_id)
# ----> 4 elif all_locations:
#       5     test_location_id = all_locations[0]["id"]
#       6     print("No bulk_created_ids, using first from all_locations:", test_location_id)
#
# NameError: name 'all_locations' is not defined

# %%
if not test_location_id:
    raise RuntimeError("No test_location_id available. Run previous cells first.")

url = f"{BASE_URL}/locations/{test_location_id}"
res = requests.get(url)

print("Status:", res.status_code)
print(json.dumps(res.json(), indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 if not test_location_id:
#       2     raise RuntimeError("No test_location_id available. Run previous cells first.")
#       4 url = f"{BASE_URL}/locations/{test_location_id}"
#
# NameError: name 'test_location_id' is not defined

# %%
update_payload = {
    "name": "Updated Test Location",
    "price_level": 3,
}

url = f"{BASE_URL}/locations/{test_location_id}"
res = requests.put(url, json=update_payload)

print("Status:", res.status_code)
print(json.dumps(res.json(), indent=2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       1 update_payload = {
#       2     "name": "Updated Test Location",
#       3     "price_level": 3,
#       4 }
# ----> 6 url = f"{BASE_URL}/locations/{test_location_id}"
#       7 res = requests.put(url, json=update_payload)
#       9 print("Status:", res.status_code)
#
# NameError: name 'test_location_id' is not defined

# %%
import os

image_path = "test_image.jpg"  # change if needed

if os.path.exists(image_path):
    url = f"{BASE_URL}/locations/{test_location_id}/images"
    with open(image_path, "rb") as f:
        files = {"file": (os.path.basename(image_path), f, "image/jpeg")}
        res = requests.post(url, files=files)

    print("Status:", res.status_code)
    print(json.dumps(res.json(), indent=2))
else:
    print(f"Image file not found: {image_path}. Skipping image upload test.")

print('Status:', res.status_code)
print('Response:', res.text)
# Out:
# Image file not found: test_image.jpg. Skipping image upload test.
# Status: 500
# Response: Internal Server Error

# %%
tags_payload = {
    "tags": ["hiking", "scenic", "sunset"]
}

url = f"{BASE_URL}/locations/{test_location_id}/tags"
res = requests.post(url, json=tags_payload)

print("Status:", res.status_code)
tags_response = res.json()
print(json.dumps(tags_response, indent=2))

tag_ids = [t.get("id") for t in tags_response.get("added_tags", []) if t.get("id") is not None]
tag_ids

print('Status:', res.status_code)
print('Response:', res.text)

# %%
if tag_ids:
    tag_id = tag_ids[0]
    url = f"{BASE_URL}/locations/{test_location_id}/tags/{tag_id}"
    res = requests.delete(url)

    print("Status:", res.status_code)
    print(json.dumps(res.json(), indent=2))
else:
    print("No tag_ids available to delete.")

# %%
if not USER_ID:
    print("USER_ID is not set. Skipping /locations/recommended test.")
else:
    url = f"{BASE_URL}/locations/recommended?limit=10"
    res = requests.get(url, headers=HEADERS)
    print("Status:", res.status_code)
    print(json.dumps(res.json(), indent=2))
# Out:
# Status: 500
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[18], line 7
#       5 res = requests.get(url, headers=HEADERS)
#       6 print("Status:", res.status_code)
# ----> 7 print(json.dumps(res.json(), indent=2))
#
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
cleanup = False  # set to True if you want to delete the test location

if cleanup and test_location_id:
    url = f"{BASE_URL}/locations/{test_location_id}"
    res = requests.delete(url)
    print("Status:", res.status_code)
    print(json.dumps(res.json(), indent=2))
elif not cleanup:
    print("Cleanup is disabled. Set cleanup = True to delete the test location.")
else:
    print("No test_location_id to delete.")
# Out:
# Cleanup is disabled. Set cleanup = True to delete the test location.
