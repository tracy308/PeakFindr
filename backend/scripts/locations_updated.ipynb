# %%
import requests
import json
import random
import time

# Base URL of the FastAPI server
BASE_URL = "http://localhost:8000"

# Optional: user_id for personalized /locations/recommended
# Get this from /auth/login if you want to test recommendations
USER_ID = "4e1a0d19-a99a-4395-935c-7746cad56b70"  # e.g. "6e0e5c7e-1234-4567-890a-bcdef1234567"

HEADERS = {"X-User-ID": USER_ID} if USER_ID else {}

print("BASE_URL =", BASE_URL)
print("USER_ID =", USER_ID)
# Out:
# BASE_URL = http://localhost:8000
# USER_ID = 4e1a0d19-a99a-4395-935c-7746cad56b70

# %%
location_names = [
    "Victoria Peak", "Lion Rock", "Dragon's Back", "Mount Parker", "Lantau Peak",
    "Tai Mo Shan", "Sharp Peak", "Sunset Peak", "Needle Hill", "Ma On Shan",
    "High West", "Pat Sin Leng", "Jardine's Lookout", "The Twins", "Castle Peak",
    "Pineapple Mountain", "Shing Mun Reservoir", "Aberdeen Peak", "Clear Water Bay Peak",
    "Ap Lei Chau Trail", "Cape D’Aguilar", "Sai Wan Peak", "Hawk's Nest", "Tung Chung Valley"
]

areas = ["Central", "Kowloon", "New Territories", "Lantau", "Hong Kong Island"]
price_levels = [1, 2, 3, 4]

bulk_created_ids = []

for name in location_names:
    payload = {
        "name": name,
        "description": f"A scenic location known as {name}.",
        "maps_url": "https://maps.example.com",
        "price_level": random.choice(price_levels),
        "area": random.choice(areas),
    }

    url = f"{BASE_URL}/locations/"
    try:
        res = requests.post(url, json=payload)
        print(f"Created {name} → Status {res.status_code}")
        print('Status:', res.status_code)
        print('Response:', res.text)
        data = res.json()
        loc_id = data.get("id")
        if loc_id:
            bulk_created_ids.append(loc_id)
    except Exception as e:
        print(f"Error creating {name}: {e}")

time.sleep(0.5)
print("\nTotal created:", len(bulk_created_ids))
bulk_created_ids[:5]
# Out:
# Created Victoria Peak → Status 200
# Status: 200
# Response: {"name":"Victoria Peak","description":"A scenic location known as Victoria Peak.","maps_url":"https://maps.example.com","price_level":3,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"4ab958b3-45ef-4c03-acdb-c35c3927733d","created_at":"2025-11-24T02:23:55.261847+08:00"}
# Created Lion Rock → Status 200
# Status: 200
# Response: {"name":"Lion Rock","description":"A scenic location known as Lion Rock.","maps_url":"https://maps.example.com","price_level":4,"area":"Kowloon","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"8154713a-4a48-4ed6-a4a0-6cd0506e96d5","created_at":"2025-11-24T02:23:55.297211+08:00"}
# Created Dragon's Back → Status 200
# Status: 200
# Response: {"name":"Dragon's Back","description":"A scenic location known as Dragon's Back.","maps_url":"https://maps.example.com","price_level":1,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"26121411-20b9-49fd-afa9-b696a16e6434","created_at":"2025-11-24T02:23:55.313393+08:00"}
# Created Mount Parker → Status 200
# Status: 200
# Response: {"name":"Mount Parker","description":"A scenic location known as Mount Parker.","maps_url":"https://maps.example.com","price_level":1,"area":"New Territories","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"61d7c6da-c199-4fbf-9f1a-7b8837d7efd6","created_at":"2025-11-24T02:23:55.327789+08:00"}
# Created Lantau Peak → Status 200
# Status: 200
# Response: {"name":"Lantau Peak","description":"A scenic location known as Lantau Peak.","maps_url":"https://maps.example.com","price_level":2,"area":"New Territories","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"39c5ce02-a032-4601-b85b-58b8f7bc836a","created_at":"2025-11-24T02:23:55.342976+08:00"}
# Created Tai Mo Shan → Status 200
# Status: 200
# Response: {"name":"Tai Mo Shan","description":"A scenic location known as Tai Mo Shan.","maps_url":"https://maps.example.com","price_level":3,"area":"Kowloon","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"dc937420-5de1-4115-a5e9-9b1a513bdc6f","created_at":"2025-11-24T02:23:55.358364+08:00"}
# Created Sharp Peak → Status 200
# Status: 200
# Response: {"name":"Sharp Peak","description":"A scenic location known as Sharp Peak.","maps_url":"https://maps.example.com","price_level":2,"area":"New Territories","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"4c51d729-73f0-436e-a64b-01ab20878447","created_at":"2025-11-24T02:23:55.375544+08:00"}
# Created Sunset Peak → Status 200
# Status: 200
# Response: {"name":"Sunset Peak","description":"A scenic location known as Sunset Peak.","maps_url":"https://maps.example.com","price_level":3,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"49e20c79-340a-4b6c-9e69-ea16fa093431","created_at":"2025-11-24T02:23:55.389973+08:00"}
# Created Needle Hill → Status 200
# Status: 200
# Response: {"name":"Needle Hill","description":"A scenic location known as Needle Hill.","maps_url":"https://maps.example.com","price_level":2,"area":"Lantau","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"de4684ca-196e-4c7e-b7a7-76bbfedb5bad","created_at":"2025-11-24T02:23:55.405573+08:00"}
# Created Ma On Shan → Status 200
# Status: 200
# Response: {"name":"Ma On Shan","description":"A scenic location known as Ma On Shan.","maps_url":"https://maps.example.com","price_level":1,"area":"New Territories","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"f37ef97e-d657-4b39-9325-ed28ad240bd0","created_at":"2025-11-24T02:23:55.419976+08:00"}
# Created High West → Status 200
# Status: 200
# Response: {"name":"High West","description":"A scenic location known as High West.","maps_url":"https://maps.example.com","price_level":4,"area":"New Territories","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"41631825-b966-4f10-9f8d-5af054a341fe","created_at":"2025-11-24T02:23:55.437164+08:00"}
# Created Pat Sin Leng → Status 200
# Status: 200
# Response: {"name":"Pat Sin Leng","description":"A scenic location known as Pat Sin Leng.","maps_url":"https://maps.example.com","price_level":1,"area":"New Territories","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"9ebf4869-888c-4ef5-87b5-0441280b03bf","created_at":"2025-11-24T02:23:55.453808+08:00"}
# Created Jardine's Lookout → Status 200
# Status: 200
# Response: {"name":"Jardine's Lookout","description":"A scenic location known as Jardine's Lookout.","maps_url":"https://maps.example.com","price_level":4,"area":"Lantau","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"5a377abd-f0ae-4f27-be26-d33fac9c277f","created_at":"2025-11-24T02:23:55.470541+08:00"}
# Created The Twins → Status 200
# Status: 200
# Response: {"name":"The Twins","description":"A scenic location known as The Twins.","maps_url":"https://maps.example.com","price_level":2,"area":"Kowloon","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"4e0f1c0f-7fd5-4525-80b2-3ce365e0b372","created_at":"2025-11-24T02:23:55.486351+08:00"}
# Created Castle Peak → Status 200
# Status: 200
# Response: {"name":"Castle Peak","description":"A scenic location known as Castle Peak.","maps_url":"https://maps.example.com","price_level":1,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"4c850591-16f3-4642-a2d4-1b6d46a9b52b","created_at":"2025-11-24T02:23:55.500616+08:00"}
# Created Pineapple Mountain → Status 200
# Status: 200
# Response: {"name":"Pineapple Mountain","description":"A scenic location known as Pineapple Mountain.","maps_url":"https://maps.example.com","price_level":3,"area":"Kowloon","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"5ea096b2-da56-4117-a89b-0df6271996be","created_at":"2025-11-24T02:23:55.514732+08:00"}
# Created Shing Mun Reservoir → Status 200
# Status: 200
# Response: {"name":"Shing Mun Reservoir","description":"A scenic location known as Shing Mun Reservoir.","maps_url":"https://maps.example.com","price_level":2,"area":"Hong Kong Island","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"8c757350-cfaf-48b8-9d5a-2b1480d92cf0","created_at":"2025-11-24T02:23:55.525391+08:00"}
# Created Aberdeen Peak → Status 200
# Status: 200
# Response: {"name":"Aberdeen Peak","description":"A scenic location known as Aberdeen Peak.","maps_url":"https://maps.example.com","price_level":3,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"dffa1d90-f14e-4370-baa7-f783fedf3195","created_at":"2025-11-24T02:23:55.539582+08:00"}
# Created Clear Water Bay Peak → Status 200
# Status: 200
# Response: {"name":"Clear Water Bay Peak","description":"A scenic location known as Clear Water Bay Peak.","maps_url":"https://maps.example.com","price_level":3,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"e7816b84-8f61-442a-8d91-082a5c3cd66a","created_at":"2025-11-24T02:23:55.550662+08:00"}
# Created Ap Lei Chau Trail → Status 200
# Status: 200
# Response: {"name":"Ap Lei Chau Trail","description":"A scenic location known as Ap Lei Chau Trail.","maps_url":"https://maps.example.com","price_level":1,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"52890554-b7c4-4b2d-b19b-9355aa591177","created_at":"2025-11-24T02:23:55.563226+08:00"}
# Created Cape D’Aguilar → Status 200
# Status: 200
# Response: {"name":"Cape D’Aguilar","description":"A scenic location known as Cape D’Aguilar.","maps_url":"https://maps.example.com","price_level":2,"area":"Hong Kong Island","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"996e3e60-942c-4a35-95e7-87df25daae78","created_at":"2025-11-24T02:23:55.577038+08:00"}
# Created Sai Wan Peak → Status 200
# Status: 200
# Response: {"name":"Sai Wan Peak","description":"A scenic location known as Sai Wan Peak.","maps_url":"https://maps.example.com","price_level":3,"area":"Kowloon","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"67d0ea1f-d735-4946-8e1b-25288460923e","created_at":"2025-11-24T02:23:55.591525+08:00"}
# Created Hawk's Nest → Status 200
# Status: 200
# Response: {"name":"Hawk's Nest","description":"A scenic location known as Hawk's Nest.","maps_url":"https://maps.example.com","price_level":4,"area":"Kowloon","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"e3a5d11e-9d40-4e6b-92db-ab754335c1f0","created_at":"2025-11-24T02:23:55.603048+08:00"}
# Created Tung Chung Valley → Status 200
# Status: 200
# Response: {"name":"Tung Chung Valley","description":"A scenic location known as Tung Chung Valley.","maps_url":"https://maps.example.com","price_level":3,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"678e5259-7ebb-48de-928c-2204684f885c","created_at":"2025-11-24T02:23:55.620628+08:00"}
#
# Total created: 24
# ['4ab958b3-45ef-4c03-acdb-c35c3927733d',
#  '8154713a-4a48-4ed6-a4a0-6cd0506e96d5',
#  '26121411-20b9-49fd-afa9-b696a16e6434',
#  '61d7c6da-c199-4fbf-9f1a-7b8837d7efd6',
#  '39c5ce02-a032-4601-b85b-58b8f7bc836a']

# %%
url = f"{BASE_URL}/locations/"
res = requests.get(url)

print("Status:", res.status_code)
all_locations = res.json()
print("Total locations returned:", len(all_locations))
print(json.dumps(all_locations[:3], indent=2))  # show first 3
# Out:
# Status: 200
# Total locations returned: 52
# [
#   {
#     "name": "Victoria Peak",
#     "description": "The highest hill on Hong Kong Island with panoramic skyline views.",
#     "maps_url": "https://maps.app.goo.gl/CxbF1j1xo2FqiHzH8",
#     "price_level": 2,
#     "area": "Hong Kong Island",
#     "region": null,
#     "summary": null,
#     "duration": null,
#     "opening_hours": null,
#     "id": "de3763f6-41a4-4370-bb03-0baa7f921ecc",
#     "created_at": "2025-11-18T19:44:52.369903+08:00"
#   },
#   {
#     "name": "Tsim Sha Tsui Promenade",
#     "description": "Iconic waterfront walkway.",
#     "maps_url": "https://maps.app.goo.gl/msnmEiW7NiyDLjMu9",
#     "price_level": 1,
#     "area": "Kowloon",
#     "region": null,
#     "summary": null,
#     "duration": null,
#     "opening_hours": null,
#     "id": "70389361-b298-4a67-84cc-1a03953b41bc",
#     "created_at": "2025-11-18T19:54:39.240075+08:00"
#   },
#   {
#     "name": "Mong Kok Night Market",
#     "description": "Bustling night market with food and fashion.",
#     "maps_url": "https://maps.app.goo.gl/kWZEtMhAYjvUJo4p7",
#     "price_level": 1,
#     "area": "Kowloon",
#     "region": null,
#     "summary": null,
#     "duration": null,
#     "opening_hours": null,
#     "id": "727b8cf6-22ee-4df6-a0a1-416d38e75bb5",
#     "created_at": "2025-11-18T19:55:18.084744+08:00"
#   }
# ]

# %%
# Example: filter by area and price_level
url = f"{BASE_URL}/locations/?area=Central&price_level=2"
res = requests.get(url)

print("Status:", res.status_code)
filtered_locations = res.json()
print("Filtered locations count:", len(filtered_locations))
print(json.dumps(filtered_locations[:3], indent=2))
# Out:
# Status: 200
# Filtered locations count: 0
# []

# %%
if bulk_created_ids:
    test_location_id = bulk_created_ids[0]
    print("Using test_location_id from bulk_created_ids:", test_location_id)
elif all_locations:
    test_location_id = all_locations[0]["id"]
    print("No bulk_created_ids, using first from all_locations:", test_location_id)
else:
    test_location_id = None
    print("No locations available to test.")

test_location_id
# Out:
# Using test_location_id from bulk_created_ids: 4ab958b3-45ef-4c03-acdb-c35c3927733d
# '4ab958b3-45ef-4c03-acdb-c35c3927733d'

# %%
if not test_location_id:
    raise RuntimeError("No test_location_id available. Run previous cells first.")

url = f"{BASE_URL}/locations/{test_location_id}"
res = requests.get(url)

print("Status:", res.status_code)
print(json.dumps(res.json(), indent=2))
# Out:
# Status: 200
# {
#   "location": {
#     "name": "Victoria Peak",
#     "description": "A scenic location known as Victoria Peak.",
#     "maps_url": "https://maps.example.com",
#     "price_level": 3,
#     "area": "Central",
#     "region": null,
#     "summary": null,
#     "duration": null,
#     "opening_hours": null,
#     "id": "4ab958b3-45ef-4c03-acdb-c35c3927733d",
#     "created_at": "2025-11-24T02:23:55.261847+08:00"
#   },
#   "images": [],
#   "tags": []
# }

# %%
update_payload = {
    "name": "Updated Test Location",
    "price_level": 3,
}

url = f"{BASE_URL}/locations/{test_location_id}"
res = requests.put(url, json=update_payload)

print("Status:", res.status_code)
print(json.dumps(res.json(), indent=2))
# Out:
# Status: 200
# {
#   "name": "Updated Test Location",
#   "description": "A scenic location known as Victoria Peak.",
#   "maps_url": "https://maps.example.com",
#   "price_level": 3,
#   "area": "Central",
#   "region": null,
#   "summary": null,
#   "duration": null,
#   "opening_hours": null,
#   "id": "4ab958b3-45ef-4c03-acdb-c35c3927733d",
#   "created_at": "2025-11-24T02:23:55.261847+08:00"
# }

# %%
import os

image_path = "test_image.jpg"  # change if needed

if os.path.exists(image_path):
    url = f"{BASE_URL}/locations/{test_location_id}/images"
    with open(image_path, "rb") as f:
        files = {"file": (os.path.basename(image_path), f, "image/jpeg")}
        res = requests.post(url, files=files)

    print("Status:", res.status_code)
    print(json.dumps(res.json(), indent=2))
else:
    print(f"Image file not found: {image_path}. Skipping image upload test.")

print('Status:', res.status_code)
print('Response:', res.text)
# Out:
# Image file not found: test_image.jpg. Skipping image upload test.
# Status: 200
# Response: {"name":"Updated Test Location","description":"A scenic location known as Victoria Peak.","maps_url":"https://maps.example.com","price_level":3,"area":"Central","region":null,"summary":null,"duration":null,"opening_hours":null,"id":"4ab958b3-45ef-4c03-acdb-c35c3927733d","created_at":"2025-11-24T02:23:55.261847+08:00"}

# %%
tags_payload = {
    "tags": ["hiking", "scenic", "sunset"]
}

url = f"{BASE_URL}/locations/{test_location_id}/tags"
res = requests.post(url, json=tags_payload)

print("Status:", res.status_code)
tags_response = res.json()
print(json.dumps(tags_response, indent=2))

tag_ids = [t.get("id") for t in tags_response.get("added_tags", []) if t.get("id") is not None]
tag_ids

print('Status:', res.status_code)
print('Response:', res.text)
# Out:
# Status: 200
# {
#   "added_tags": [
#     {
#       "name": "hiking",
#       "id": 11
#     },
#     {
#       "name": "scenic",
#       "id": 2
#     },
#     {
#       "name": "sunset",
#       "id": 5
#     }
#   ]
# }
# Status: 200
# Response: {"added_tags":[{"name":"hiking","id":11},{"name":"scenic","id":2},{"name":"sunset","id":5}]}

# %%
if tag_ids:
    tag_id = tag_ids[0]
    url = f"{BASE_URL}/locations/{test_location_id}/tags/{tag_id}"
    res = requests.delete(url)

    print("Status:", res.status_code)
    print(json.dumps(res.json(), indent=2))
else:
    print("No tag_ids available to delete.")

# %%
if not USER_ID:
    print("USER_ID is not set. Skipping /locations/recommended test.")
else:
    url = f"{BASE_URL}/locations/recommended?limit=10"
    res = requests.get(url, headers=HEADERS)
    print("Status:", res.status_code)
    print(json.dumps(res.json(), indent=2))
# Out:
# Status: 500
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File /opt/homebrew/Cellar/python@3.12/3.12.4/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[18], line 7
#       5 res = requests.get(url, headers=HEADERS)
#       6 print("Status:", res.status_code)
# ----> 7 print(json.dumps(res.json(), indent=2))
#
# File ~/Desktop/PeakFindr/backend/venv/lib/python3.12/site-packages/requests/models.py:980, in Response.json(self, **kwargs)
#     976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 980     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
cleanup = False  # set to True if you want to delete the test location

if cleanup and test_location_id:
    url = f"{BASE_URL}/locations/{test_location_id}"
    res = requests.delete(url)
    print("Status:", res.status_code)
    print(json.dumps(res.json(), indent=2))
elif not cleanup:
    print("Cleanup is disabled. Set cleanup = True to delete the test location.")
else:
    print("No test_location_id to delete.")
# Out:
# Cleanup is disabled. Set cleanup = True to delete the test location.
